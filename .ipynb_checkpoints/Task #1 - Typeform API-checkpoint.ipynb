# %% [markdown]
# # Task #1
# Purpose: To display API requests skills in Python

# %%
import requests
import json
from pandas.io.json import json_normalize

# %% [markdown]
# ## Obtaining UID
# In order to access the form responses, we need to obtain our UID using the given API key.

# %%
# Send GET request to Typeform using API key to get UID
payload = {'key': 'ac83034cfa742c0f79c26e9a612b4ba7e2aa0d3d'}

firstRequest = requests.get('https://api.typeform.com/v1/forms', params=payload)
print('Accessing: {}'.format(firstRequest.url))

idResponse = firstRequest.json()
print(idResponse[0].keys())

UID, name = idResponse[0].values()
# Out:
# Accessing: https://api.typeform.com/v1/forms?key=ac83034cfa742c0f79c26e9a612b4ba7e2aa0d3d
# dict_keys(['id', 'name'])

# %% [markdown]
# ## Obtaining Form Responses
# We can now access the form responses using the UID and API key.

# %%
# Send GET request to typeform with UID and API key to access the responses
secondRequest = requests.get('https://api.typeform.com/v1/form/{}'.format(UID), params=payload)
print('Accessing: {}'.format(secondRequest.url))

formResponse = secondRequest.json()
print("Response: \n" + json.dumps(formResponse, indent=2))
# Out:
# Accessing: https://api.typeform.com/v1/form/PfSNFM?key=ac83034cfa742c0f79c26e9a612b4ba7e2aa0d3d
# Response:
# {
#   "http_status": 200,
#   "stats": {
#     "responses": {
#       "showing": 16,
#       "total": 16,
#       "completed": 11
#     }
#   },
#   "questions": [
#     {
#       "id": "date_46098446",
#       "question": "This is a date field. Say \"Hello, date field!\" So, what date is today?",
#       "field_id": 46098446
#     },
#     {
#       "id": "number_46099137",
#       "question": "This is a number field. It contains\u00a0numbers. What is your favorite prime number? #GeekAllert",
#       "field_id": 46099137
#     },
#     {
#       "id": "yesno_46099317",
#       "question": "We went rogue and added the checkmark field! Is Keboola the best company in the known universe to work for?",
#       "field_id": 46099317
#     },
#     {
#       "id": "list_46100308_choice",
#       "question": "Now is time for the multi-choice question! What is your favorite kind of Pho?",
#       "field_id": 46100308
#     },
#     {
#       "id": "textarea_46100513",
#       "question": "The dirtiest data field of all data fields. The address field. The true nightmare of every data analyst!",
#       "field_id": 46100513
#     }
#   ],
#   "responses": [
#     {
#       "completed": "1",
#       "token": "7ee7cb68882c57d3c81b7503e8ec4157",
#       "metadata": {
#         "browser": "default",
#         "platform": "other",
#         "date_land": "2017-03-17 21:22:34",
#         "date_submit": "2017-03-17 21:23:50",
#         "user_agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36",
#         "referer": "https://hrkeboola.typeform.com/to/PfSNFM",
#         "network_id": "783db4e9d8"
#       },
#       "hidden": [],
#       "answers": {
#         "date_46098446": "2017-03-17",
#         "number_46099137": "3",
#         "yesno_46099317": "1",
#         "list_46100308_choice": "I love all kinds of Pho. Pho for the president!",
#         "textarea_46100513": "210 - 1461 Johnston Rd, White Rock, BC V4B 3Z4"
#       }
#     },
#     {
#       "completed": "1",
#       "token": "929fb7f0fc2c011d98d49fd807e3ba12",
#       "metadata": {
#         "browser": "default",
#         "platform": "other",
#         "date_land": "2017-03-17 21:24:06",
#         "date_submit": "2017-03-17 21:25:08",
#         "user_agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36",
#         "referer": "https://hrkeboola.typeform.com/to/PfSNFM",
#         "network_id": "783db4e9d8"
#       },
#       "hidden": [],
#       "answers": {
#         "date_46098446": "2016-12-31",
#         "number_46099137": "7",
#         "list_46100308_choice": "More ingredients, the better. I like my Pho full of taste. ",
#         "textarea_46100513": "15230 Russell Ave White Rock BC V4B"
#       }
#     },
#     {
#       "completed": "0",
#       "token": "c141209e02e6a9bf01c60ece7169b55b",
#       "metadata": {
#         "browser": "default",
#         "platform": "other",
#         "date_land": "2017-03-17 21:25:14",
#         "date_submit": "0000-00-00 00:00:00",
#         "user_agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36",
#         "referer": "https://hrkeboola.typeform.com/to/PfSNFM",
#         "network_id": "783db4e9d8"
#       },
#       "hidden": [],
#       "answers": {}
#     },
#     {
#       "completed": "1",
#       "token": "bc92448137641bd58b9296061089514e",
#       "metadata": {
#         "browser": "default",
#         "platform": "other",
#         "date_land": "2017-03-17 21:25:46",
#         "date_submit": "2017-03-17 21:27:06",
#         "user_agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36",
#         "referer": "https://hrkeboola.typeform.com/to/PfSNFM",
#         "network_id": "783db4e9d8"
#       },
#       "hidden": [],
#       "answers": {
#         "date_46098446": "1921-04-01",
#         "number_46099137": "13",
#         "yesno_46099317": "1",
#         "list_46100308_choice": "I don't eat Pho but I'll start immediately! So sorry, so Pho!",
#         "textarea_46100513": "Krizikova 488/115, 186 00 Praha 8-Karlin, Czechia"
#       }
#     },
#     {
#       "completed": "1",
#       "token": "a3b36c47a8fe8b59fb574fdebaba71ac",
#       "metadata": {
#         "browser": "default",
#         "platform": "other",
#         "date_land": "2017-03-17 21:27:15",
#         "date_submit": "2017-03-17 21:30:07",
#         "user_agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36",
#         "referer": "https://hrkeboola.typeform.com/to/PfSNFM",
#         "network_id": "783db4e9d8"
#       },
#       "hidden": [],
#       "answers": {
#         "date_46098446": "2007-01-01",
#         "number_46099137": "10",
#         "yesno_46099317": "1",
#         "list_46100308_choice": "Beef and basic is my choice of Pho.",
#         "textarea_46100513": "30 Cecil St, #19-06 Singapore 049712"
#       }
#     },
#     {
#       "completed": "1",
#       "token": "7a66caab65c92d6ffdfb1d8cea7ded26",
#       "metadata": {
#         "browser": "default",
#         "platform": "other",
#         "date_land": "2017-03-17 21:31:22",
#         "date_submit": "2017-03-17 21:32:34",
#         "user_agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36",
#         "referer": "https://hrkeboola.typeform.com/to/PfSNFM",
#         "network_id": "783db4e9d8"
#       },
#       "hidden": [],
#       "answers": {
#         "date_46098446": "2015-02-16",
#         "number_46099137": "17",
#         "yesno_46099317": "1",
#         "textarea_46100513": "WeWork 9 Devonshire Square, London EC2M 4YD, United Kingdom"
#       }
#     },
#     {
#       "completed": "1",
#       "token": "25d7e68aee7db37ce8d282bb969942cc",
#       "metadata": {
#         "browser": "default",
#         "platform": "other",
#         "date_land": "2017-03-17 21:32:43",
#         "date_submit": "2017-03-17 21:34:04",
#         "user_agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36",
#         "referer": "https://hrkeboola.typeform.com/to/PfSNFM",
#         "network_id": "783db4e9d8"
#       },
#       "hidden": [],
#       "answers": {
#         "number_46099137": "101",
#         "list_46100308_choice": "I love all kinds of Pho. Pho for the president!",
#         "textarea_46100513": "1150 Davie St, Vancouver, BC V6E 1N1"
#       }
#     },
#     {
#       "completed": "1",
#       "token": "4fc901e2410e7d5ccc8c228e0ba858fe",
#       "metadata": {
#         "browser": "default",
#         "platform": "other",
#         "date_land": "2017-03-23 19:35:28",
#         "date_submit": "2017-03-23 19:37:34",
#         "user_agent": "Mozilla/5.0 (X11; Fedora; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36",
#         "referer": "https://inhumantsar.typeform.com/to/PfSNFM",
#         "network_id": "e367c5e34e"
#       },
#       "hidden": [],
#       "answers": {
#         "date_46098446": "2017-03-23",
#         "number_46099137": "7",
#         "yesno_46099317": "1",
#         "list_46100308_choice": "Beef and basic is my choice of Pho.",
#         "textarea_46100513": "123 Evergreen Terrace\nSpringfield, IL 12345"
#       }
#     },
#     {
#       "completed": "1",
#       "token": "4e25bb5a8fc1b27dd11e86dba040a815",
#       "metadata": {
#         "browser": "default",
#         "platform": "other",
#         "date_land": "2017-03-23 19:37:45",
#         "date_submit": "2017-03-23 19:38:23",
#         "user_agent": "Mozilla/5.0 (X11; Fedora; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36",
#         "referer": "https://inhumantsar.typeform.com/to/PfSNFM",
#         "network_id": "e367c5e34e"
#       },
#       "hidden": [],
#       "answers": {
#         "date_46098446": "2017-03-23",
#         "number_46099137": "1",
#         "textarea_46100513": "Left the multi-choice blank, just because"
#       }
#     },
#     {
#       "completed": "1",
#       "token": "9411fa542da1c8e9b13f56378bc0c32f",
#       "metadata": {
#         "browser": "default",
#         "platform": "other",
#         "date_land": "2017-03-23 19:38:26",
#         "date_submit": "2017-03-23 19:41:22",
#         "user_agent": "Mozilla/5.0 (X11; Fedora; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36",
#         "referer": "https://inhumantsar.typeform.com/to/PfSNFM",
#         "network_id": "e367c5e34e"
#       },
#       "hidden": [],
#       "answers": {
#         "date_46098446": "2017-03-23",
#         "number_46099137": "7",
#         "yesno_46099317": "1",
#         "list_46100308_choice": "Beef and basic is my choice of Pho.",
#         "textarea_46100513": "123 Evergreen Terrace\nSpringfield, IL 12345"
#       }
#     },
#     {
#       "completed": "0",
#       "token": "181f5d2663a263bfecf1bee91b6cd90d",
#       "metadata": {
#         "browser": "default",
#         "platform": "other",
#         "date_land": "2017-03-24 06:19:30",
#         "date_submit": "0000-00-00 00:00:00",
#         "user_agent": "Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36",
#         "referer": "https://akriox.typeform.com/to/PfSNFM",
#         "network_id": "d0f38b6c46"
#       },
#       "hidden": [],
#       "answers": {}
#     },
#     {
#       "completed": "1",
#       "token": "1fc9d95dd8a19c39057f74a718afdade",
#       "metadata": {
#         "browser": "default",
#         "platform": "other",
#         "date_land": "2017-03-24 06:20:54",
#         "date_submit": "2017-03-24 06:24:52",
#         "user_agent": "Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36",
#         "referer": "https://akriox.typeform.com/to/PfSNFM",
#         "network_id": "d0f38b6c46"
#       },
#       "hidden": [],
#       "answers": {
#         "date_46098446": "2017-03-23",
#         "number_46099137": "73",
#         "yesno_46099317": "1",
#         "list_46100308_choice": "I don't eat Pho but I'll start immediately! So sorry, so Pho!",
#         "textarea_46100513": "All work and no play makes jack a dull boy.\nAll work and no play makes jack a dull boy.\nAll work and no play makes jack a dull boy.\nAll work and no play makes jack a dull boy.\nAll work and no play makes jack a dull boy."
#       }
#     },
#     {
#       "completed": "0",
#       "token": "12261639cf6a91cf6e7039e215175e22",
#       "metadata": {
#         "browser": "default",
#         "platform": "other",
#         "date_land": "2017-03-25 06:04:39",
#         "date_submit": "0000-00-00 00:00:00",
#         "user_agent": "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36",
#         "referer": "https://hrkeboola.typeform.com/to/PfSNFM",
#         "network_id": "ef6bc82c6b"
#       },
#       "hidden": [],
#       "answers": {}
#     },
#     {
#       "completed": "0",
#       "token": "02cb24a7ca4994eb0ed57fc1d2aa4a7e",
#       "metadata": {
#         "browser": "default",
#         "platform": "other",
#         "date_land": "2017-03-26 23:19:33",
#         "date_submit": "0000-00-00 00:00:00",
#         "user_agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/57.0.2987.110 Safari/537.36",
#         "referer": "https://hrkeboola.typeform.com/to/PfSNFM",
#         "network_id": "f38f4a9b9b"
#       },
#       "hidden": [],
#       "answers": {}
#     },
#     {
#       "completed": "1",
#       "token": "cb9311b79dd7459c9d1c9beb88b86b9b",
#       "metadata": {
#         "browser": "default",
#         "platform": "other",
#         "date_land": "2017-03-27 00:15:21",
#         "date_submit": "2017-03-27 00:17:17",
#         "user_agent": "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36",
#         "referer": "https://hrkeboola.typeform.com/to/PfSNFM",
#         "network_id": "79e5a6d45b"
#       },
#       "hidden": [],
#       "answers": {
#         "date_46098446": "2017-03-26",
#         "number_46099137": "7",
#         "yesno_46099317": "1",
#         "list_46100308_choice": "More ingredients, the better. I like my Pho full of taste. ",
#         "textarea_46100513": "MacDonald on Willingdon Ave, Burnaby"
#       }
#     },
#     {
#       "completed": "0",
#       "token": "f59205ba28b31a4d4bd1986616e51aba",
#       "metadata": {
#         "browser": "default",
#         "platform": "other",
#         "date_land": "2017-03-28 03:10:48",
#         "date_submit": "0000-00-00 00:00:00",
#         "user_agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_3) AppleWebKit/602.4.8 (KHTML, like Gecko) Version/10.0.3 Safari/602.4.8",
#         "referer": "https://hrkeboola.typeform.com/to/PfSNFM",
#         "network_id": "ce34597b49"
#       },
#       "hidden": [],
#       "answers": {}
#     }
#   ]
# }

# %% [markdown]
# ## Displaying the Data
# Load the JSON response into a DataFrame for viewing.

# %%
# json_normalize because it produces a flattened table
df = json_normalize(formResponse['responses'])
df
# Out:
#    answers.date_46098446                       answers.list_46100308_choice  \
# 0             2017-03-17    I love all kinds of Pho. Pho for the president!
# 1             2016-12-31  More ingredients, the better. I like my Pho fu...
# 2                    NaN                                                NaN
# 3             1921-04-01  I don't eat Pho but I'll start immediately! So...
# 4             2007-01-01                Beef and basic is my choice of Pho.
# 5             2015-02-16                                                NaN
# 6                    NaN    I love all kinds of Pho. Pho for the president!
# 7             2017-03-23                Beef and basic is my choice of Pho.
# 8             2017-03-23                                                NaN
# 9             2017-03-23                Beef and basic is my choice of Pho.
# 10                   NaN                                                NaN
# 11            2017-03-23  I don't eat Pho but I'll start immediately! So...
# 12                   NaN                                                NaN
# 13                   NaN                                                NaN
# 14            2017-03-26  More ingredients, the better. I like my Pho fu...
# 15                   NaN                                                NaN
#
#    answers.number_46099137                          answers.textarea_46100513  \
# 0                        3     210 - 1461 Johnston Rd, White Rock, BC V4B 3Z4
# 1                        7                15230 Russell Ave White Rock BC V4B
# 2                      NaN                                                NaN
# 3                       13  Krizikova 488/115, 186 00 Praha 8-Karlin, Czechia
# 4                       10               30 Cecil St, #19-06 Singapore 049712
# 5                       17  WeWork 9 Devonshire Square, London EC2M 4YD, U...
# 6                      101               1150 Davie St, Vancouver, BC V6E 1N1
# 7                        7       123 Evergreen Terrace\nSpringfield, IL 12345
# 8                        1          Left the multi-choice blank, just because
# 9                        7       123 Evergreen Terrace\nSpringfield, IL 12345
# 10                     NaN                                                NaN
# 11                      73  All work and no play makes jack a dull boy.\nA...
# 12                     NaN                                                NaN
# 13                     NaN                                                NaN
# 14                       7               MacDonald on Willingdon Ave, Burnaby
# 15                     NaN                                                NaN
#
#    answers.yesno_46099317 completed hidden metadata.browser  \
# 0                       1         1     []          default
# 1                     NaN         1     []          default
# 2                     NaN         0     []          default
# 3                       1         1     []          default
# 4                       1         1     []          default
# 5                       1         1     []          default
# 6                     NaN         1     []          default
# 7                       1         1     []          default
# 8                     NaN         1     []          default
# 9                       1         1     []          default
# 10                    NaN         0     []          default
# 11                      1         1     []          default
# 12                    NaN         0     []          default
# 13                    NaN         0     []          default
# 14                      1         1     []          default
# 15                    NaN         0     []          default
#
#      metadata.date_land metadata.date_submit metadata.network_id  \
# 0   2017-03-17 21:22:34  2017-03-17 21:23:50          783db4e9d8
# 1   2017-03-17 21:24:06  2017-03-17 21:25:08          783db4e9d8
# 2   2017-03-17 21:25:14  0000-00-00 00:00:00          783db4e9d8
# 3   2017-03-17 21:25:46  2017-03-17 21:27:06          783db4e9d8
# 4   2017-03-17 21:27:15  2017-03-17 21:30:07          783db4e9d8
# 5   2017-03-17 21:31:22  2017-03-17 21:32:34          783db4e9d8
# 6   2017-03-17 21:32:43  2017-03-17 21:34:04          783db4e9d8
# 7   2017-03-23 19:35:28  2017-03-23 19:37:34          e367c5e34e
# 8   2017-03-23 19:37:45  2017-03-23 19:38:23          e367c5e34e
# 9   2017-03-23 19:38:26  2017-03-23 19:41:22          e367c5e34e
# 10  2017-03-24 06:19:30  0000-00-00 00:00:00          d0f38b6c46
# 11  2017-03-24 06:20:54  2017-03-24 06:24:52          d0f38b6c46
# 12  2017-03-25 06:04:39  0000-00-00 00:00:00          ef6bc82c6b
# 13  2017-03-26 23:19:33  0000-00-00 00:00:00          f38f4a9b9b
# 14  2017-03-27 00:15:21  2017-03-27 00:17:17          79e5a6d45b
# 15  2017-03-28 03:10:48  0000-00-00 00:00:00          ce34597b49
#
#    metadata.platform                            metadata.referer  \
# 0              other    https://hrkeboola.typeform.com/to/PfSNFM
# 1              other    https://hrkeboola.typeform.com/to/PfSNFM
# 2              other    https://hrkeboola.typeform.com/to/PfSNFM
# 3              other    https://hrkeboola.typeform.com/to/PfSNFM
# 4              other    https://hrkeboola.typeform.com/to/PfSNFM
# 5              other    https://hrkeboola.typeform.com/to/PfSNFM
# 6              other    https://hrkeboola.typeform.com/to/PfSNFM
# 7              other  https://inhumantsar.typeform.com/to/PfSNFM
# 8              other  https://inhumantsar.typeform.com/to/PfSNFM
# 9              other  https://inhumantsar.typeform.com/to/PfSNFM
# 10             other       https://akriox.typeform.com/to/PfSNFM
# 11             other       https://akriox.typeform.com/to/PfSNFM
# 12             other    https://hrkeboola.typeform.com/to/PfSNFM
# 13             other    https://hrkeboola.typeform.com/to/PfSNFM
# 14             other    https://hrkeboola.typeform.com/to/PfSNFM
# 15             other    https://hrkeboola.typeform.com/to/PfSNFM
#
#                                   metadata.user_agent  \
# 0   Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_3...
# 1   Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_3...
# 2   Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_3...
# 3   Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_3...
# 4   Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_3...
# 5   Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_3...
# 6   Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_3...
# 7   Mozilla/5.0 (X11; Fedora; Linux x86_64) AppleW...
# 8   Mozilla/5.0 (X11; Fedora; Linux x86_64) AppleW...
# 9   Mozilla/5.0 (X11; Fedora; Linux x86_64) AppleW...
# 10  Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebK...
# 11  Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebK...
# 12  Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKi...
# 13  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 14  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 15  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_3...
#
#                                token
# 0   7ee7cb68882c57d3c81b7503e8ec4157
# 1   929fb7f0fc2c011d98d49fd807e3ba12
# 2   c141209e02e6a9bf01c60ece7169b55b
# 3   bc92448137641bd58b9296061089514e
# 4   a3b36c47a8fe8b59fb574fdebaba71ac
# 5   7a66caab65c92d6ffdfb1d8cea7ded26
# 6   25d7e68aee7db37ce8d282bb969942cc
# 7   4fc901e2410e7d5ccc8c228e0ba858fe
# 8   4e25bb5a8fc1b27dd11e86dba040a815
# 9   9411fa542da1c8e9b13f56378bc0c32f
# 10  181f5d2663a263bfecf1bee91b6cd90d
# 11  1fc9d95dd8a19c39057f74a718afdade
# 12  12261639cf6a91cf6e7039e215175e22
# 13  02cb24a7ca4994eb0ed57fc1d2aa4a7e
# 14  cb9311b79dd7459c9d1c9beb88b86b9b
# 15  f59205ba28b31a4d4bd1986616e51aba
